# %% [markdown]
# # Creation of the Document Repository (Wikipedia)

# %% [markdown]
# ## 1 Identification of the corpus from DBPedia
#
# ### 1.1 Get DBPedia concepts from the root concept

# %%
#############################################
# Creating tables:
# Unique pages:
# Table of cleaning pages:
#############################################

from bd_vr import BDdatos

db = BDdatos()
con = db.conectar()

tableDB = 'DBCSubconceptsVR'  # Table with subconcepts 

cur = con.cursor()

# Creating table:
cur.execute(u"""CREATE TABLE """ + tableDB + """ (`date` VARCHAR(12) DEFAULT NULL,
  `r` TEXT CHARACTER SET utf8 COLLATE utf8_general_ci,
  `c1` TEXT CHARACTER SET utf8 COLLATE utf8_general_ci,
  `c2` TEXT CHARACTER SET utf8 COLLATE utf8_general_ci,
  `c3` TEXT,
  `level` INT DEFAULT NULL);""")

db.saveDB(con)
db.closeDB(con)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDF, XML
from bd_vr import BDdatos
import codecs
import json
from datetime import date

db = BDdatos()
con = db.conectar()

# Variables to start the query process. To change de rootConcept.

rootConcept = ["http://dbpedia.org/resource/Category:Virtual_reality"] # set the root concept
e = "http://live.dbpedia.org/sparql"  # set the EndPoint: DBPedia Live


def getSubConcepts():
    """
        Get sub-soncepts of the root concept(s). Retrieve subconcepts located in three hops.
    """
    
    varP = ['c1', 'c2', 'c3', 'level']
    sparql = SPARQLWrapper(e)
    
    query = """select distinct ?level ?r ?c1 ?c2 ?c3
    {
        {VALUES (?r ?level) {(<%s> 1)}
            # ?r ^skos:broader ?c1.}
        union
        {VALUES (?r ?level) {(<%s> 2)}
            # ?r ^skos:broader ?c1. ?c1 ^skos:broader ?c2.}
        union
        {VALUES (?r ?level) {(<%s> 3)}
            # ?r ^skos:broader ?c3. ?c3 ^skos:broader ?c2. ?c2 ^skos:broader ?c1.}
    }
    """
    numSC = 0 # number of subconcepts
    print("\t Processing...")
    for res in rootConcept:
        print("Root concept:", res)  
        sparql.setQuery(query%(res, res, res))
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        for result in results["results"]["bindings"]:
            numSC += 1
            var1 = var2 = var3 = var4 = ''
            if varP[0] in result:
                var1 = result[varP[0]]["value"]
            if varP[1] in result:
                var2 = result[varP[1]]["value"]
            if varP[2] in result:
                var3 = result[varP[2]]["value"]
            if varP[3] in result:
                var4 = result[varP[3]]["value"]
            db.DBCSubconceptsVR(db, date.today().strftime("%d/%m/%Y"), res, var1, var2, var3, var4, tableDB)
    
    print("Number of results:", numSC)
    
    
# To RUN:
getSubConcepts()  # Get subconcepts
# Out:
# 	 Processing...
# Root concept: http://dbpedia.org/resource/Category:Virtual_reality
# Number of results: 772

# %% [markdown]
# ### 1.2 Getting a unique list of concepts:

# %%
from bd_vr import BDdatos

db = BDdatos()
con = db.conectar()

print("...Getting unique concepts")

tableDB = 'DBCSubconceptsVR'
tableDBlist = 'DBCSubconceptsVRList'
tableDBIDs = 'DBCSubconceptsVRIDs'

db.DBCGetUniqueConcepts(db, tableDB, tableDBlist, tableDBIDs)

db.saveDB(con)
db.closeDB(con)
# Out:
# ...Getting unique concepts

# %% [markdown]
# ### 1.3. Getting Wikipage links and their metadata from DBPedia Live:
#
# <b>a. Creating the table:</b>

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDF, XML
from datetime import date
from bd_vr import BDdatos

db = BDdatos()
con = db.conectar()

e = "http://live.dbpedia.org/sparql" 
otable = 'DBSubconcepts_WikiPages'  # table to fill with wikipages data

cur = con.cursor()
# Create table:
cur.execute(u"""CREATE TABLE """ + otable + """ (`date` date, `concept` text, """ +
                   """ `dbrResource` text, `wikiPage` text, `wikiPageModified` date DEFAULT NULL, `max_outDegree` INT DEFAULT NULL) """ +
                   """ ENGINE=InnoDB DEFAULT CHARSET=utf8;""")

db.saveDB(con)
db.closeDB(con)

# %% [markdown]
# <b> b. Querying data: </b>

# %%
con = db.conectar()


###########
# Get Pages:

def getWikiPagesFromDBConcepts(stable, otable, l1, l2):
    cur = con.cursor()
    print("Getting links from DBpedia:")

    # Insert data into new table:
    cur.execute("""select distinct id, c from """ + stable + """ where id >""" +str(l1)+' and id <= ' + str(l2))
    rowList = cur.fetchall()
    for row in rowList:
        idC = row[0]
        cat = row[1]
        print(idC, cat)
        results = getMetadata(cat)
        if results:
            for result in results:
                res = page = max_modif  = ''
                max_outDegree = 0
                res = result['r']["value"]
                if 'primaryTopic' in result:
                    page = result['primaryTopic']["value"]
                if 'max_modif' in result:
                    max_modif = result['max_modif']["value"]
                if 'max_outDegree' in result:
                    max_outDegree = result['max_outDegree']["value"]
            
                db.DBSubconcepts_WikiPages(db, date.today().strftime("%Y-%m-%d"), cat, res, page, max_modif, max_outDegree, otable)

def getMetadata(cat):
    sparql = SPARQLWrapper(e)
    # Pendiente el type de cada recurso:
    q = """SELECT DISTINCT ?r ?primaryTopic (substr(str(xsd:date(max(?modif))), 1, 10) AS ?max_modif) 
    (str(max(?outDegree)) AS ?max_outDegree)
    WHERE{
    VALUES ?c {<%s>}
    # ?r dct:subject ?c .
    OPTIONAL {?r dbo:wikiPageModified ?modif.}
    OPTIONAL {?r dbo:wikiPageOutDegree ?outDegree.}
    OPTIONAL {?r foaf:isPrimaryTopicOf ?primaryTopic.}
    }"""
    sparql.setQuery(q%(cat))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results["results"]["bindings"]

#########################
# Manual check after run

# Send range of ids to get pages: 281 (max id from tableDBIDs = DBCSubconceptsCOVIDIDs)
getWikiPagesFromDBConcepts(tableDBIDs, otable, 0, 282)
# Out:
# Getting links from DBpedia:
# 1 http://dbpedia.org/resource/Category:Virtual_reality_organizations
# 2 http://dbpedia.org/resource/Category:Virtual_reality_communities
# 3 http://dbpedia.org/resource/Category:Holography
# 4 http://dbpedia.org/resource/Category:Virtual_reality_games
# 5 http://dbpedia.org/resource/Category:Virtual_reality_works
# 6 http://dbpedia.org/resource/Category:Virtual_reality_in_fiction
# 7 http://dbpedia.org/resource/Category:Haptic_technology
# 8 http://dbpedia.org/resource/Category:Ray_tracing_(graphics)
# 9 http://dbpedia.org/resource/Category:Psychoacoustics
# 10 http://dbpedia.org/resource/Category:Mixed_reality
# 11 http://dbpedia.org/resource/Category:Virtual_reality_pioneers
# 12 http://dbpedia.org/resource/Category:Virtual_avatars
# 13 http://dbpedia.org/resource/Category:Virtual_economy
# 14 http://dbpedia.org/resource/Category:Virtual_reality_headsets
# 15 http://dbpedia.org/resource/Category:Video_gaming
# 16 http://dbpedia.org/resource/Category:DVD_interactive_technology
# 17 http://dbpedia.org/resource/Category:CD-ROM-based_consoles
# 18 http://dbpedia.org/resource/Category:Online_gaming_services
# 19 http://dbpedia.org/resource/Category:ALL.Net_games
# 20 http://dbpedia.org/resource/Category:Dedicated_consoles
# 21 http://dbpedia.org/resource/Category:Digital_rights_management
# 22 http://dbpedia.org/resource/Category:NESiCAxLive_games
# 23 http://dbpedia.org/resource/Category:Pack-in_video_games
# 24 http://dbpedia.org/resource/Category:Free-to-play_video_games
# 25 http://dbpedia.org/resource/Category:Video_game_compilations
# 26 http://dbpedia.org/resource/Category:Video_game_expansion_packs
# 27 http://dbpedia.org/resource/Category:Cloud_gaming
# 28 http://dbpedia.org/resource/Category:Video_games_with_downloadable_content
# 29 http://dbpedia.org/resource/Category:Episodic_video_games
# 30 http://dbpedia.org/resource/Category:Video_game_retailers
# 31 http://dbpedia.org/resource/Category:Video_game_downloadable_content_packs
# 32 http://dbpedia.org/resource/Category:LaserDisc_video_games
# 33 http://dbpedia.org/resource/Category:Cloud_gaming_services
# 34 http://dbpedia.org/resource/Category:Video_game_downloadable_content
# 35 http://dbpedia.org/resource/Category:Online_video_game_services
# 36 http://dbpedia.org/resource/Category:Subscription_video_game_services
# 37 http://dbpedia.org/resource/Category:Video_game_platform_emulators
# 38 http://dbpedia.org/resource/Category:Video_game_art
# 39 http://dbpedia.org/resource/Category:Works_about_video_games
# 40 http://dbpedia.org/resource/Category:LGBT_and_video_games
# 41 http://dbpedia.org/resource/Category:Gender_and_video_games
# 42 http://dbpedia.org/resource/Category:Works_based_on_video_games
# 43 http://dbpedia.org/resource/Category:Video_game_censorship
# 44 http://dbpedia.org/resource/Category:Video_game_memes
# 45 http://dbpedia.org/resource/Category:Video_game_fandom
# 46 http://dbpedia.org/resource/Category:Video_game_journalism
# 47 http://dbpedia.org/resource/Category:Years_in_video_gaming
# 48 http://dbpedia.org/resource/Category:Video_game_law
# 49 http://dbpedia.org/resource/Category:Speedrunning
# 50 http://dbpedia.org/resource/Category:Video_game_websites
# 51 http://dbpedia.org/resource/Category:Video_game_webcomics
# 52 http://dbpedia.org/resource/Category:Video_game_cheating
# 53 http://dbpedia.org/resource/Category:Violence_in_video_games
# 54 http://dbpedia.org/resource/Category:Video_arcades
# 55 http://dbpedia.org/resource/Category:Gamer_advocacy_groups
# 56 http://dbpedia.org/resource/Category:Game_jams
# 57 http://dbpedia.org/resource/Category:People_in_the_video_game_industry
# 58 http://dbpedia.org/resource/Category:Video_game_awards
# 59 http://dbpedia.org/resource/Category:Harassment_incidents_in_video_games
# 60 http://dbpedia.org/resource/Category:Video_game_museums
# 61 http://dbpedia.org/resource/Category:Esports
# 62 http://dbpedia.org/resource/Category:Video_game_video_content
# 63 http://dbpedia.org/resource/Category:Twitch_streamers
# 64 http://dbpedia.org/resource/Category:Let's_Players
# 65 http://dbpedia.org/resource/Category:Video_gaming_by_year
# 66 http://dbpedia.org/resource/Category:Bad_technology
# 67 http://dbpedia.org/resource/Category:Criticism_of_bad_technology
# 68 http://dbpedia.org/resource/Category:Bad_television
# 69 http://dbpedia.org/resource/Category:Twitch_(service)_streamers
# 70 http://dbpedia.org/resource/Category:Cheating_in_video_games
# 71 http://dbpedia.org/resource/Category:HTC_Vive_games
# 72 http://dbpedia.org/resource/Category:PlayStation_VR_games
# 73 http://dbpedia.org/resource/Category:Oculus_Rift_games
# 74 http://dbpedia.org/resource/Category:Virtual_Boy_games
# 75 http://dbpedia.org/resource/Category:Samsung_Gear_games
# 76 http://dbpedia.org/resource/Category:Oculus_Quest_games
# 77 http://dbpedia.org/resource/Category:Valve_Index_games
# 78 http://dbpedia.org/resource/Category:Game_researchers
# 79 http://dbpedia.org/resource/Category:Video_game_conferences
# 80 http://dbpedia.org/resource/Category:Video_game_universities
# 81 http://dbpedia.org/resource/Category:Holography_in_films
# 82 http://dbpedia.org/resource/Category:Fictional_illusionists
# 83 http://dbpedia.org/resource/Category:Holography_in_television
# 84 http://dbpedia.org/resource/Category:Dead_Space_games
# 85 http://dbpedia.org/resource/Category:Dead_Space_(franchise)_games
# 86 http://dbpedia.org/resource/Category:Marathon_(video_game)
# 87 http://dbpedia.org/resource/Category:Die_Hard_arcade_and_video_games
# 88 http://dbpedia.org/resource/Category:Video_games_with_expansion_packs
# 89 http://dbpedia.org/resource/Category:Video_game_remakes
# 90 http://dbpedia.org/resource/Category:Video_game_franchises_by_year
# 91 http://dbpedia.org/resource/Category:Arcade_game_franchises
# 92 http://dbpedia.org/resource/Category:Splinter_Cell
# 93 http://dbpedia.org/resource/Category:Rainbow_Six
# 94 http://dbpedia.org/resource/Category:Video_game_lists_by_franchise
# 95 http://dbpedia.org/resource/Category:Video_games_based_on_Star_Trek
# 96 http://dbpedia.org/resource/Category:Spy_Fox
# 97 http://dbpedia.org/resource/Category:Quake
# 98 http://dbpedia.org/resource/Category:Wikipedia_categories_named_after_video_game_franchises
# 99 http://dbpedia.org/resource/Category:Unreal
# 100 http://dbpedia.org/resource/Category:Video_game_franchises_by_company
# 101 http://dbpedia.org/resource/Category:Civilization_franchise
# 102 http://dbpedia.org/resource/Category:Ghost_Recon
# 103 http://dbpedia.org/resource/Category:Siren
# 104 http://dbpedia.org/resource/Category:Spore_(2008_video_game)
# 105 http://dbpedia.org/resource/Category:Driver_series
# 106 http://dbpedia.org/resource/Category:Wolfenstein_series
# 107 http://dbpedia.org/resource/Category:Mafia_series
# 108 http://dbpedia.org/resource/Category:Fable
# 109 http://dbpedia.org/resource/Category:Hitman_(series)
# 110 http://dbpedia.org/resource/Category:Tengai_Maky?
# 111 http://dbpedia.org/resource/Category:Anno_(video_game_series)
# 112 http://dbpedia.org/resource/Category:Just_Dance
# 113 http://dbpedia.org/resource/Category:Works_based_on_video_games_by_franchise
# 114 http://dbpedia.org/resource/Category:Video_game_remasters
# 115 http://dbpedia.org/resource/Category:Video_game_series_by_genre
# 116 http://dbpedia.org/resource/Category:Everybody's_Golf
# 117 http://dbpedia.org/resource/Category:Tales_(video_game_series)
# 118 http://dbpedia.org/resource/Category:Atlantis_(video_game_series)
# 119 http://dbpedia.org/resource/Category:Lists_of_video_game_franchises
# 120 http://dbpedia.org/resource/Category:Video_game_franchises_by_decade
# 121 http://dbpedia.org/resource/Category:Video_game_franchises_by_year_of_disestablishment
# 122 http://dbpedia.org/resource/Category:Video_game_franchises_by_century
# 123 http://dbpedia.org/resource/Category:Bus_Simulator_series
# 124 http://dbpedia.org/resource/Category:S.T.A.L.K.E.R._(series)
# 125 http://dbpedia.org/resource/Category:Video_game_franchises_by_year_of_introduction
# 126 http://dbpedia.org/resource/Category:Video_game_franchises_by_genre
# 127 http://dbpedia.org/resource/Category:Bus_Simulator
# 128 http://dbpedia.org/resource/Category:S.T.A.L.K.E.R.
# 129 http://dbpedia.org/resource/Category:Video_games_based_on_Wacky_Races
# 130 http://dbpedia.org/resource/Category:Arcade_video_game_franchises
# 131 http://dbpedia.org/resource/Category:Arcade_hardware
# 132 http://dbpedia.org/resource/Category:Video_game_storage_media
# 133 http://dbpedia.org/resource/Category:Nintendo_hardware
# 134 http://dbpedia.org/resource/Category:Japan-only_video_game_hardware
# 135 http://dbpedia.org/resource/Category:Video_game_accessories
# 136 http://dbpedia.org/resource/Category:Video_game_platforms
# 137 http://dbpedia.org/resource/Category:Modchips
# 138 http://dbpedia.org/resource/Category:Microsoft_video_game_hardware
# 139 http://dbpedia.org/resource/Category:Video_games_by_theme
# 140 http://dbpedia.org/resource/Category:History_of_video_games
# 141 http://dbpedia.org/resource/Category:Advergames
# 142 http://dbpedia.org/resource/Category:Video_games_by_genre
# 143 http://dbpedia.org/resource/Category:Video_games_by_game_engine
# 144 http://dbpedia.org/resource/Category:Video_gaming_operating_systems
# 145 http://dbpedia.org/resource/Category:Video_games_adapted_into_novels
# 146 http://dbpedia.org/resource/Category:Video_games_by_company
# 147 http://dbpedia.org/resource/Category:Video_games_by_development_status
# 148 http://dbpedia.org/resource/Category:Video_games_by_graphical_style
# 149 http://dbpedia.org/resource/Category:Video_games_by_setting
# 150 http://dbpedia.org/resource/Category:Video_games_by_source
# 151 http://dbpedia.org/resource/Category:Video_games_by_year
# 152 http://dbpedia.org/resource/Category:Wikipedia_categories_named_after_games
# 153 http://dbpedia.org/resource/Category:Video_games_with_6_degrees_of_freedom
# 154 http://dbpedia.org/resource/Category:Video_game_lists
# 155 http://dbpedia.org/resource/Category:Video_games_by_software_license
# 156 http://dbpedia.org/resource/Category:Video_games_by_platform
# 157 http://dbpedia.org/resource/Category:Video_games_with_alternate_versions
# 158 http://dbpedia.org/resource/Category:Video_game_mods
# 159 http://dbpedia.org/resource/Category:Video_games_containing_microtransactions
# 160 http://dbpedia.org/resource/Category:Video_games_by_language
# 161 http://dbpedia.org/resource/Category:Video_gaming_by_country
# 162 http://dbpedia.org/resource/Category:Video_games_by_country
# 163 http://dbpedia.org/resource/Category:Video_games_by_staff
# 164 http://dbpedia.org/resource/Category:Lists_of_video_games_from_5th_generation_video_game_consoles_in_chronological_order
# 165 http://dbpedia.org/resource/Category:Lists_of_video_games_from_6th_generation_video_game_consoles_in_chronological_order
# 166 http://dbpedia.org/resource/Category:Video_games_by_physics_engine
# 167 http://dbpedia.org/resource/Category:Video_games_by_narrative_form
# 168 http://dbpedia.org/resource/Category:Video_games_by_century
# 169 http://dbpedia.org/resource/Category:Video_games_by_type_of_adaptation
# 170 http://dbpedia.org/resource/Category:Video_games_by_character
# 171 http://dbpedia.org/resource/Category:Hackers_in_video_games
# 172 http://dbpedia.org/resource/Category:Motion_capture_in_video_games
# 173 http://dbpedia.org/resource/Category:Video_games_by_decade
# 174 http://dbpedia.org/resource/Category:New_Retro_Games
# 175 http://dbpedia.org/resource/Category:Quotations_from_video_games
# 176 http://dbpedia.org/resource/Category:Video_games_by_gameplay_element
# 177 http://dbpedia.org/resource/Category:Hunting_in_video_games
# 178 http://dbpedia.org/resource/Category:Video_games_with_permanent_death
# 179 http://dbpedia.org/resource/Category:Video_games_using_code_wheel_copy_protection
# 180 http://dbpedia.org/resource/Category:New_media_art
# 181 http://dbpedia.org/resource/Category:Video_games
# 182 http://dbpedia.org/resource/Category:Web_documentaries
# 183 http://dbpedia.org/resource/Category:Interactive_films
# 184 http://dbpedia.org/resource/Category:Video_game_development_competitions
# 185 http://dbpedia.org/resource/Category:Video_game_festivals
# 186 http://dbpedia.org/resource/Category:Video_game_conventions
# 187 http://dbpedia.org/resource/Category:Video_game_exhibitions
# 188 http://dbpedia.org/resource/Category:Nintendo_events
# 189 http://dbpedia.org/resource/Category:Machinima_based_on_Second_Life
# 190 http://dbpedia.org/resource/Category:Second_Life_screenshots
# 191 http://dbpedia.org/resource/Category:Video_games_with_commentaries
# 192 http://dbpedia.org/resource/Category:Video_game_sound
# 193 http://dbpedia.org/resource/Category:Video_game_development_companies
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# c:\users\andre\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     507                                raw=raw, buffered=buffered,
# --> 508                                raw_as_string=raw_as_string)
#     509         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Incorrect date value: '' for column 'wikiPageModified' at row 1
#
# During handling of the above exception, another exception occurred:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-14-b46e09d07654> in <module>
#      52
#      53 # Send range of ids to get pages: 281 (max id from tableDBIDs = DBCSubconceptsCOVIDIDs)
# ---> 54 getWikiPagesFromDBConcepts(tableDBIDs, otable, 0, 282)
#      55
#
# <ipython-input-14-b46e09d07654> in getWikiPagesFromDBConcepts(stable, otable, l1, l2)
#      29                     max_outDegree = result['max_outDegree']["value"]
#      30
# ---> 31                 db.DBSubconcepts_WikiPages(db, date.today().strftime("%Y-%m-%d"), cat, res, page, max_modif, max_outDegree, otable)
#      32
#      33 def getMetadata(cat):
#
# ~\Desktop\UTPL\10º\Sistemas basados en conocimiento\Proyecto\wikipedia\bd_vr.py in DBSubconcepts_WikiPages(db, self, date, c, r, p, d, l, table)
#      73
#      74         # Insert data
# ---> 75         cursor.execute(u"""INSERT INTO """ + table + """ values (%s, %s, %s, %s, %s, %s)""", (date, c, r, p, d, l))
#      76         db.saveDB(con)
#      77         db.closeDB(con)
#
# c:\users\andre\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     269             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                          buffered=self._buffered,
# --> 271                                          raw_as_string=self._raw_as_string)
#     272         except MySQLInterfaceError as exc:
#     273             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# c:\users\andre\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     509         except MySQLInterfaceError as exc:
#     510             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 511                                              sqlstate=exc.sqlstate)
#     512         except AttributeError:
#     513             if self._unix_socket:
#
# DataError: 1292 (22007): Incorrect date value: '' for column 'wikiPageModified' at row 1

# %% [markdown]
# <b> c. Validating Wikipage links (there are some redirects)</b>

# %%
#############################################
# Creating tables:
# Unique pages:
# Table of cleaning pages:
#############################################

from SPARQLWrapper import SPARQLWrapper, JSON, RDF, XML
from datetime import date
from bd_vr import BDdatos

db = BDdatos()
con = db.conectar()


ttable = 'WikiPagesIDs_tmp'  # Temporal table with unique wikipage links retrieved from DBPedia
rtable = 'WikiPagesRedirects'

cur = con.cursor()
# Create table:
cur.execute(u"""CREATE TABLE """ + ttable + """ (id INT AUTO_INCREMENT PRIMARY KEY)"""+
            """SELECT DISTINCT wikipage page, count(*) AS freq """ +
            """FROM """ + otable + """ GROUP BY page HAVING length(wikipage) > 0;
""")

cur.execute(u"""CREATE TABLE `""" + rtable + """` (`date` DATE, id INT, """+ 
            """`dbpUrl` TEXT, `returnedUrl` TEXT);""")

db.saveDB(con)
db.closeDB(con)

# %%
#############################################
# Getting redirects from Wikipedia
#############################################

from datetime import date
from bd_vr import BDdatos
import codecs
import json
import re 
from bs4 import BeautifulSoup 

db = BDdatos()
con = db.conectar()


URL = "https://en.wikipedia.org/w/api.php"
import requests
S = requests.Session()

################    
# Get Redirects:
def getRedirects(l1, l2):
    cur = con.cursor()
    print("Getting redirects:")
    cur = con.cursor()
    cur.execute("""SELECT distinct id, page FROM """ + ttable +  """ WHERE id >""" +str(l1)+' and id <= ' + str(l2))
    rowList = cur.fetchall()
    for row in rowList:
        idP = row[0]
        dbpediaUrl = row[1]
        print(idP, dbpediaUrl)
        returnedUrl = getLink(dbpediaUrl).replace('https://', 'http://')
        db.WikiPagesRedirects(db, date.today().strftime("%Y-%m-%d"), idP, dbpediaUrl, returnedUrl, rtable)

def getLink(page):
    """Check if it is a redirect"""
    r = requests.get(page)
    c = r.content
    soupC = BeautifulSoup(c,"html.parser")
    link=soupC.find('link',{'rel':'canonical'})['href']
    return link


#########################
# Manual check after run
# To run: urls (getting from DBPedia) to clean
getRedirects(0, 3410) # The second parameter is the max id in ttable = WikiPagesIDs_tmp
# Out:
# Getting redirects:
# 1 http://en.wikipedia.org/wiki/National_Film_Board_of_Canada
# 2 http://en.wikipedia.org/wiki/Animaze_Montreal_International_Film_Festival
# 3 http://en.wikipedia.org/wiki/Virtual_Reality_Applications_Center
# 4 http://en.wikipedia.org/wiki/VRAC
# 5 http://en.wikipedia.org/wiki/International_Stereoscopic_Union
# 6 http://en.wikipedia.org/wiki/Virtual_Reality_and_Education_Laboratory
# 7 http://en.wikipedia.org/wiki/Immerse_Learning
# 311 http://en.wikipedia.org/wiki/Tixel
# 312 http://en.wikipedia.org/wiki/Aura_Interactor
# 313 http://en.wikipedia.org/wiki/Affective_haptics
# 314 http://en.wikipedia.org/wiki/Surgery_simulator
# 315 http://en.wikipedia.org/wiki/Mo-cap_suit
# 316 http://en.wikipedia.org/wiki/Visuo-haptic_mixed_reality
# 317 http://en.wikipedia.org/wiki/DualShock
# 318 http://en.wikipedia.org/wiki/BlackBerry_Torch
# 319 http://en.wikipedia.org/wiki/Telehaptics
# 320 http://en.wikipedia.org/wiki/List_of_PC_games_with_force_feedback_support
# 321 http://en.wikipedia.org/wiki/Stereotaxy
# 322 http://en.wikipedia.org/wiki/Novint_Technologies
# 323 http://en.wikipedia.org/wiki/Haptic_suit
# 324 http://en.wikipedia.org/wiki/BlackBerry_Storm
# 325 http://en.wikipedia.org/wiki/Woojer
# 326 http://en.wikipedia.org/wiki/Tactile_technology
# 327 http://en.wikipedia.org/wiki/Refreshable_braille_display
# 328 http://en.wikipedia.org/wiki/Sixaxis
# 329 http://en.wikipedia.org/wiki/BlackBerry_Storm_2
# 330 http://en.wikipedia.org/wiki/Battlefield_V
# 331 http://en.wikipedia.org/wiki/DirectX_Raytracing
# 332 http://en.wikipedia.org/wiki/List_of_ray_tracing_software
# 333 http://en.wikipedia.org/wiki/Rayshade
# 334 http://en.wikipedia.org/wiki/Wolfenstein:_Ray_Traced
# 335 http://en.wikipedia.org/wiki/OptiX
# 336 http://en.wikipedia.org/wiki/Quake_Wars:_Ray_Traced
# 337 http://en.wikipedia.org/wiki/Ray-tracing_hardware
# 338 http://en.wikipedia.org/wiki/Progressive_refinement
# 339 http://en.wikipedia.org/wiki/Distributed_ray_tracing
# 340 http://en.wikipedia.org/wiki/OpenRL
# 341 http://en.wikipedia.org/wiki/Ray_tracing_(graphics)
# 342 http://en.wikipedia.org/wiki/Brainwave_entrainment
# 343 http://en.wikipedia.org/wiki/Psychoacoustics
# 344 http://en.wikipedia.org/wiki/Equal-loudness_contour
# 345 http://en.wikipedia.org/wiki/Auditory_illusion
# 346 http://en.wikipedia.org/wiki/Robinson–Dadson_curves
# 347 http://en.wikipedia.org/wiki/A_duplex_theory_of_pitch_perception
# 348 http://en.wikipedia.org/wiki/Mel_scale
# 349 http://en.wikipedia.org/wiki/Perceptual-based_3D_sound_localization
# 350 http://en.wikipedia.org/wiki/Backward_masking
# 351 http://en.wikipedia.org/wiki/Pitch_(music)
# 352 http://en.wikipedia.org/wiki/Missing_fundamental
# 353 http://en.wikipedia.org/wiki/Tinnitus_masker
# 354 http://en.wikipedia.org/wiki/Critical_band
# 355 http://en.wikipedia.org/wiki/Pure_tone
# 356 http://en.wikipedia.org/wiki/Precedence_effect
# 357 http://en.wikipedia.org/wiki/Stevens's_power_law
# 358 http://en.wikipedia.org/wiki/Beat_(acoustics)
# 359 http://en.wikipedia.org/wiki/Fletcher–Munson_curves
# 360 http://en.wikipedia.org/wiki/Bark_scale
# 361 http://en.wikipedia.org/wiki/Prairie_madness
# 719 http://en.wikipedia.org/wiki/AudioLock
# 720 http://en.wikipedia.org/wiki/Audio_Home_Recording_Act
# 721 http://en.wikipedia.org/wiki/Secure_Digital_Container
# 722 http://en.wikipedia.org/wiki/Consumer_Broadband_and_Digital_Television_Promotion_Act
# 723 http://en.wikipedia.org/wiki/Against_DRM_license
# 724 http://en.wikipedia.org/wiki/Compliance_and_Robustness
# 725 http://en.wikipedia.org/wiki/Rpmsg
# 726 http://en.wikipedia.org/wiki/PC1_cipher
# 727 http://en.wikipedia.org/wiki/Rightscorp
# 728 http://en.wikipedia.org/wiki/Television_encryption
# 729 http://en.wikipedia.org/wiki/DVD_region_code
# 730 http://en.wikipedia.org/wiki/Sony_BMG_copy_protection_rootkit_scandal
# 731 http://en.wikipedia.org/wiki/Triton_(content_delivery)
# 732 http://en.wikipedia.org/wiki/Analog_hole
# 733 http://en.wikipedia.org/wiki/Hardware_restriction
# 734 http://en.wikipedia.org/wiki/4C_Entity
# 735 http://en.wikipedia.org/wiki/Trymedia
# 736 http://en.wikipedia.org/wiki/Defective_by_Design
# 737 http://en.wikipedia.org/wiki/Regional_lockout
# 738 http://en.wikipedia.org/wiki/Copy_protection
# 739 http://en.wikipedia.org/wiki/XrML
# 740 http://en.wikipedia.org/wiki/Self-Protecting_Digital_Content
# 741 http://en.wikipedia.org/wiki/Conditional_access
# 742 http://en.wikipedia.org/wiki/The_Right_to_Read
# 743 http://en.wikipedia.org/wiki/Selectable_Output_Control
# 744 http://en.wikipedia.org/wiki/Open_Music_Initiative
# 745 http://en.wikipedia.org/wiki/Digital_Entertainment_Content_Ecosystem
# 746 http://en.wikipedia.org/wiki/Lektz
# 747 http://en.wikipedia.org/wiki/Content_ID_(system)
# 748 http://en.wikipedia.org/wiki/Digital_distribution
# 749 http://en.wikipedia.org/wiki/List_of_copy_protection_schemes
# 750 http://en.wikipedia.org/wiki/Conax
# 751 http://en.wikipedia.org/wiki/Information_rights_management
# 752 http://en.wikipedia.org/wiki/Digital_locker
# 753 http://en.wikipedia.org/wiki/Modissa
# 754 http://en.wikipedia.org/wiki/Digital_rights_management
# 755 http://en.wikipedia.org/wiki/Seed_(sculpture)
# 756 http://en.wikipedia.org/wiki/Perpetual_access
# 757 http://en.wikipedia.org/wiki/John_Walker_(programmer)
# 758 http://en.wikipedia.org/wiki/Software_protection_dongle
# 759 http://en.wikipedia.org/wiki/CEG_TEK_International
# 760 http://en.wikipedia.org/wiki/Always-on_DRM
# 761 http://en.wikipedia.org/wiki/NTSC-C
# 762 http://en.wikipedia.org/wiki/Digital_video_fingerprinting
# 763 http://en.wikipedia.org/wiki/CcREL
# 764 http://en.wikipedia.org/wiki/Windows_Genuine_Advantage
# 765 http://en.wikipedia.org/wiki/Ray_Adams
# 766 http://en.wikipedia.org/wiki/Controlled_digital_lending
# 767 http://en.wikipedia.org/wiki/Trace_vector_decoder
# 768 http://en.wikipedia.org/wiki/Online_pass
# 769 http://en.wikipedia.org/wiki/Azure_Information_Protection
# 3372 http://en.wikipedia.org/wiki/Kanon_Mizushiro
# 3373 http://en.wikipedia.org/wiki/Gypsy_(comics)
# 3374 http://en.wikipedia.org/wiki/Mastermind_(Jason_Wyngarde)
# 3375 http://en.wikipedia.org/wiki/Loki_(comics)
# 3376 http://en.wikipedia.org/wiki/White_Witch
# 3377 http://en.wikipedia.org/wiki/Duke_of_Deception
# 3378 http://en.wikipedia.org/wiki/Samurai_(Super_Friends)
# 3379 http://en.wikipedia.org/wiki/Trucy_Wright
# 3380 http://en.wikipedia.org/wiki/Kyoko_Sakura
# 3381 http://en.wikipedia.org/wiki/Fatale_(Marvel_Comics)
# 3382 http://en.wikipedia.org/wiki/Hikari_Chono
# 3383 http://en.wikipedia.org/wiki/Nene_Konoe
# 3384 http://en.wikipedia.org/wiki/Phobia_(comics)
# 3385 http://en.wikipedia.org/wiki/King_Standish
# 3386 http://en.wikipedia.org/wiki/Karnilla
# 3387 http://en.wikipedia.org/wiki/El_Dorado_(Super_Friends)
# 3388 http://en.wikipedia.org/wiki/Candyman_(character)
# 3389 http://en.wikipedia.org/wiki/Airi_Kirara
# 3390 http://en.wikipedia.org/wiki/Ruruka_Hanayama
# 3391 http://en.wikipedia.org/wiki/Phoenix_Ikki
# 3392 http://en.wikipedia.org/wiki/Doctor_Occult
# 3393 http://en.wikipedia.org/wiki/Zoisite_(Sailor_Moon)
# 3394 http://en.wikipedia.org/wiki/Despero
# 3395 http://en.wikipedia.org/wiki/Morgan_le_Fay_(Marvel_Comics)
# 3396 http://en.wikipedia.org/wiki/King_Chimera
# 3397 http://en.wikipedia.org/wiki/Luminus_(character)
# 3398 http://en.wikipedia.org/wiki/Laura_Fukuouji
# 3399 http://en.wikipedia.org/wiki/Rinko_Kougyoku
# 3400 http://en.wikipedia.org/wiki/Sasuke_Uchiha
# 3401 http://en.wikipedia.org/wiki/Circe_(character)
# 3402 http://en.wikipedia.org/wiki/Akari_Sakura
# 3403 http://en.wikipedia.org/wiki/Harlequin_(comics)
# 3404 http://en.wikipedia.org/wiki/Itachi_Uchiha
# 3405 http://en.wikipedia.org/wiki/Agatha_Harkness
# 3406 http://en.wikipedia.org/wiki/Lady_Mastermind
# 3407 http://en.wikipedia.org/wiki/Olivier_(comics)
# 3408 http://en.wikipedia.org/wiki/Zorua_and_Zoroark
# 3409 http://en.wikipedia.org/wiki/Loki_(Marvel_Cinematic_Universe)
# 3410 http://en.wikipedia.org/wiki/Kokoro_Yotsuba

# %%
#############################################
# Creating tables:
# Unique pages:
#############################################

from bd_vr import BDdatos

db = BDdatos()
con = db.conectar()

otable = 'WikiPagesIDs'

cur = con.cursor()


# Create table:
cur.execute(u"""CREATE TABLE """ + otable + """ (id INT AUTO_INCREMENT PRIMARY KEY)  
SELECT DISTINCT returnedUrl AS wikipageUrl FROM """ + rtable + """;""")

# Drop temporal table:
cur.execute(u"""DROP TABLE """ + ttable + """;""")

db.saveDB(con)
db.closeDB(con)

# %%
#La tabla WikiPagesIDs contiene los links de las páginas de la Wikipedia.
